# %% [markdown]
# <a href="https://colab.research.google.com/github/saikumarreddykorsapati-source/DataScience_Masters_Assignments/blob/main/DSM_Assignment_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1)
#
# RGBA(Red-Green-Blue-Alpha)
# The RGB color model is extended in this specification to include “alpha” to allow specification of the opacity of a color.
#
# ---

# %% [markdown]
# 2)
#
# USE PIL.Image.Image.getpixel() TO RETURN THE RGB VALUES OF A PIXEL.
#
# Call PIL.Image.Image.getpixel((x, y)) with x as the x-coordinate and y as the y-coordinate of the pixel to return a tuple of the red, green, and blue values.
#
# ```
# filename = "sample.jpg"
# img = Image. open(filename)
# img. show() Display image.
# colors = img. getpixel((320,240)) Get the RGB values at coordinate x = 320, y = 240.
# print(colors)
# ```
#
#
#
# ---

# %% [markdown]
# 3)
#
# Many of Pillow's functions and methods take a box tuple argument. This means Pillow is expecting a tuple of four integer coordinates that represent a rectangular region in an image.
#
# ---

# %% [markdown]
# 4)
#
# PIL.Image.open() is used to open the image and then .width and .height property of Image are used to get the height and width of the image.
#
# The same results can be obtained by using .size property.
#
# ```
# # import required module
# from PIL import Image
#
# # get image
# filepath = "geeksforgeeks.png"
# img = Image.open(filepath)
#
# # get width and height
# width,height = img.size
#
# # display width and height
# print("The height of the image is: ", height)
# print("The width of the image is: ", width)
# ```
#
#
#
# ---

# %% [markdown]
# 5)
#
# numpy array
#
# ---

# %%
from PIL import Image
import numpy as np	
import urllib.request


# Opening the image and converting
# it to RGB color mode
# IMAGE_PATH => Path to the image

urllib.request.urlretrieve(
  'data:image/jpeg;base64,...',
   "ineuron.png")

img = Image.open(r"ineuron.png").convert('RGB')

# Extracting the image data &
# creating an numpy array out of it
img_arr = np.array(img)

# Turning the pixel values of the 400x400 pixels to black
img_arr[100 : 200, 0 : 100] = (0, 0, 0)

# Creating an image out of the previously modified array
img1 = Image.fromarray(img_arr)

# Displaying the image : img.show()
img1
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F75E19C9DD0>

# %% [markdown]
# ---

# %% [markdown]
# 6)
#
# img1 = Image.open(r"ineuron.png").convert('RGB')
#
#
#
#
# ```
# img1.save("filename")
# ```
#
#
#
# ---

# %% [markdown]
# 7)
#
# The 'ImageDraw' module provides simple 2D graphics support for Image Object. Generally, we use this module to create new images, annotate or retouch existing images and to generate graphics on the fly for web use. The graphics commands support the drawing of shapes and annotation of text.
#
# ---

# %% [markdown]
# 8)
#
# from PIL import ImageFont, ImageDraw
#
# ---
